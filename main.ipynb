# %% [markdown]
# **TIPOS DE DATOS**

# %%
type(42)
# Out:
# bool

# %%
type(-139)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type("hola mundo")
# Out:
# str

# %%
type("4")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# **OPERACIONES**

# %%
3+5
# Out:
# 8

# %%
3-5
# Out:
# -2

# %%
3*5
# Out:
# 15

# %%
3/5
# Out:
# 0.6

# %%
5**3
# Out:
# 125

# %%
5//3
# Out:
# 1

# %%
5%3
# Out:
# 2

# %%
(3+5//4-2)-2**4+3*(7-2)
# Out:
# 1

# %% [markdown]
# **VALORES BOOL**

# %%
5//4>3 or 2<5**2
# Out:
# True

# %%
1<2 and 5<2*4
# Out:
# True

# %% [markdown]
# **CONCATENACIÓN**

# %%
"yo soy "+"tu padre"
# Out:
# 'yo soy tu padre'

# %% [markdown]
# **REPETICIÓN**

# %%
"ja"*4
# Out:
# 'jajajaja'

# %% [markdown]
# **CONVERSIÓN DE DATOS**

# %%
"son las " + str(3+12)
# Out:
# 'son las 15'

# %%
int(3.5)
# Out:
# 3

# %%
int("3") + 12
# Out:
# 15

# %%
float(3)
# Out:
# 3.0

# %%
float("3.5") + 12
# Out:
# 15.5

# %% [markdown]
# **ALMACENANDO VALORES**

# %%
pesos_por_hora = 200
llegada = 14
(19-llegada)*pesos_por_hora
# Out:
# 1000

# %%
llegada = 20
salida = 22
(salida-llegada)*pesos_por_hora
# Out:
# 400

# %%
r = 5
pi = 3.14159
s = "el area es"
area = pi * r**2
area
# Out:
# 78.53975

# %% [markdown]
# **PRINT**

# %%
pesos_por_hora = 200
llegada = 20
salida = 22
precio = (salida - llegada )*pesos_por_hora
print(precio)
# Out:
# 400

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
print((3+5//4-2)-2**4+3*(7-2))
# Out:
# 1

# %%
fahrenheit = 91
celsius = (fahrenheit - 32)* 5/9
print(celsius)
# Out:
# 32.77777777777778

# %%
temperatura = 33
print(temperatura >= 30)
# Out:
# True

# %%
episodio = 3
print("episodio")
print(episodio)
print("del libro")
# Out:
# episodio
# 3
# del libro

# %%
episodio = 3
print("episodio" ,episodio, "de libro")
# Out:
# episodio 3 de libro

# %%
nombre = "soy cristian"
edad = 38
print("soy",nombre, end=" ")
print("y tengo" ,edad, "años" )
print("cumplidos")
# Out:
# soy soy cristian y tengo 38 años
# cumplidos

# %%
print("este print", end= " :D ")
print("no cambia", "de linea",end=";)",)
# Out:
# este print :D no cambia de linea;)

# %%
msj1 = "hoy habra"
temp = 34
msj2 = "grados"
print(msj1,temp,msj2)
# Out:
# hoy habra 34 grados

# %%
print("el tesoro", "esta", "en", sep="...")
# Out:
# el tesoro...esta...en

# %% [markdown]
# **INPUT**

# %%
nombre = input("cual es tu nombre?")
saludo = "hola"
pregunta = "como estas hoy?"
print(saludo,nombre,pregunta)
# Out:
# cual es tu nombre?dana
# hola dana como estas hoy?

# %%
lec=int(input("cuantas lecciones has visto "))
total = 15
faltan = total - lec
